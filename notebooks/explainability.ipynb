# %%
import pickle
import numpy as np
import pandas as pd
from collections import defaultdict
import matplotlib.pyplot as plt
import seaborn as sns

# %%
class PolarizationAnalysisPipeline:
    def __init__(self, pickle_path):
        self.pickle_path = pickle_path
        self.raw_data = None
        self.aggregated_data = None
        self.polarization_analysis = None
    
    def load_pickle(self):
        """Step 1: Load the pickle file"""
        print("Loading pickle file...")
        with open(self.pickle_path, 'rb') as f:
            self.raw_data = pickle.load(f)
        
        congress_nums = set()
        seeds = set()
        for key in self.raw_data.keys():
            congress_num, seed = key.split('_')
            congress_nums.add(int(congress_num))
            seeds.add(int(seed))
        
        print(f"Loaded data for {len(congress_nums)} congress sessions: {sorted(congress_nums)}")
        print(f"Using {len(seeds)} seeds: {sorted(seeds)}")
        
        return self.raw_data
    
    def aggregate_all_terms(self):
        """Step 2: Aggregate ALL terms across seeds for each congress"""
        print("Aggregating coefficients across seeds...")
        
        congress_term_coefficients = defaultdict(lambda: defaultdict(list))
        
        for key, term_coeffs in self.raw_data.items():
            congress_num, seed = key.split('_')
            congress_num = int(congress_num)
            
            for term, coefficient in term_coeffs.items():
                congress_term_coefficients[congress_num][term].append(coefficient)
        
        # Calculate aggregated statistics
        self.aggregated_data = {}
        for congress_num, terms_dict in congress_term_coefficients.items():
            self.aggregated_data[congress_num] = {}
            
            for term, coeff_list in terms_dict.items():
                mean_coeff = np.mean(coeff_list)
                self.aggregated_data[congress_num][term] = {
                    'mean_coefficient': mean_coeff,
                    'abs_coefficient': abs(mean_coeff),
                    'std_coefficient': np.std(coeff_list),
                    'n_seeds': len(coeff_list)
                }
        
        return self.aggregated_data
    
    def analyze_partisan_distinctions(self, top_n=20):
        """Step 3: Analyze top Republican vs Democrat distinguishing terms"""
        print(f"\nAnalyzing top {top_n} partisan distinguishing terms per congress...")
        
        self.polarization_analysis = {}
        
        for congress_num, terms_data in self.aggregated_data.items():
            # Sort ALL terms by absolute coefficient (most discriminative)
            sorted_terms = sorted(terms_data.items(), 
                                key=lambda x: x[1]['abs_coefficient'], 
                                reverse=True)
            
            # Get top Republican terms (positive coefficients)
            republican_terms = []
            democrat_terms = []
            
            for term, data in sorted_terms:
                if data['mean_coefficient'] > 0 and len(republican_terms) < top_n:
                    republican_terms.append({
                        'term': term,
                        'coefficient': data['mean_coefficient'],
                        'abs_coefficient': data['abs_coefficient'],
                        'std': data['std_coefficient']
                    })
                elif data['mean_coefficient'] < 0 and len(democrat_terms) < top_n:
                    democrat_terms.append({
                        'term': term,
                        'coefficient': data['mean_coefficient'],
                        'abs_coefficient': data['abs_coefficient'],
                        'std': data['std_coefficient']
                    })
                
                # Stop when we have enough of both
                if len(republican_terms) >= top_n and len(democrat_terms) >= top_n:
                    break
            
            self.polarization_analysis[congress_num] = {
                'republican_terms': republican_terms,
                'democrat_terms': democrat_terms
            }
        
        return self.polarization_analysis
    
    def print_partisan_comparison(self):
        """Print detailed partisan comparison for each congress"""
        if not self.polarization_analysis:
            print("Run analyze_partisan_distinctions() first!")
            return
        
        print("\n" + "="*80)
        print("PARTISAN LANGUAGE DISTINCTION ANALYSIS")
        print("="*80)
        
        for congress_num in sorted(self.polarization_analysis.keys()):
            data = self.polarization_analysis[congress_num]
            
            print(f"\nCONGRESS {congress_num}")
            print("-" * 50)
            
            print(f"\nTOP REPUBLICAN-DISTINGUISHING TERMS:")
            print("  (Positive coefficients - algorithm associates these with Republicans)")
            for i, term_data in enumerate(data['republican_terms'][:10], 1):
                print(f"  {i:2d}. {term_data['term']:<15} (coeff: {term_data['coefficient']:+.3f})")
            
            print(f"\nTOP DEMOCRAT-DISTINGUISHING TERMS:")
            print("  (Negative coefficients - algorithm associates these with Democrats)")
            for i, term_data in enumerate(data['democrat_terms'][:10], 1):
                print(f"  {i:2d}. {term_data['term']:<15} (coeff: {term_data['coefficient']:+.3f})")
    
    def create_polarization_evolution_df(self):
        """Create dataframe showing polarization evolution over time"""
        if not self.polarization_analysis:
            print("Run analyze_partisan_distinctions() first!")
            return None
        
        evolution_data = []
        
        for congress_num in sorted(self.polarization_analysis.keys()):
            data = self.polarization_analysis[congress_num]
            
            evolution_data.append({
                'congress': congress_num,
                'strongest_republican_term': data['republican_terms'][0]['term'] if data['republican_terms'] else None,
                'strongest_democrat_term': data['democrat_terms'][0]['term'] if data['democrat_terms'] else None
            })
        
        return pd.DataFrame(evolution_data)
    
    def compare_congress_polarization(self, congress1, congress2):
        """Compare polarization between two specific congresses"""
        if not self.polarization_analysis:
            print("Run analyze_partisan_distinctions() first!")
            return
        
        if congress1 not in self.polarization_analysis or congress2 not in self.polarization_analysis:
            print(f"Congress {congress1} or {congress2} not found in data")
            return
        
        data1 = self.polarization_analysis[congress1]
        data2 = self.polarization_analysis[congress2]
        
        print(f"\nCOMPARING CONGRESS {congress1} vs CONGRESS {congress2}")
        print("="*60)
        
        # Top terms comparison
        print(f"\nTop Republican Terms Comparison:")
        rep1_terms = [t['term'] for t in data1['republican_terms'][:5]]
        rep2_terms = [t['term'] for t in data2['republican_terms'][:5]]
        
        print(f"  Congress {congress1}: {', '.join(rep1_terms)}")
        print(f"  Congress {congress2}: {', '.join(rep2_terms)}")
        
        common_rep = set(rep1_terms) & set(rep2_terms)
        if common_rep:
            print(f"  Common terms: {', '.join(common_rep)}")
        
        print(f"\nTop Democrat Terms Comparison:")
        dem1_terms = [t['term'] for t in data1['democrat_terms'][:5]]
        dem2_terms = [t['term'] for t in data2['democrat_terms'][:5]]
        
        print(f"  Congress {congress1}: {', '.join(dem1_terms)}")
        print(f"  Congress {congress2}: {', '.join(dem2_terms)}")
        
        common_dem = set(dem1_terms) & set(dem2_terms)
        if common_dem:
            print(f"  Common terms: {', '.join(common_dem)}")
    
    def get_polarization_trend_summary(self):
        """Get summary of polarization trends"""
        evolution_df = self.create_polarization_evolution_df()
        
        if len(evolution_df) < 2:
            print("Need at least 2 congress sessions to analyze trends")
            return
        
        print("\nPOLARIZATION TREND SUMMARY")
        print("="*50)
        
        first_congress = evolution_df.iloc[0]
        last_congress = evolution_df.iloc[-1]
        
        print(f"Period: Congress {first_congress['congress']} → Congress {last_congress['congress']}")
        print(f"Analysis shows evolution in partisan language patterns over time")
        
        return evolution_df
    
    def run_polarization_pipeline(self, top_n=20):
        """Run the complete polarization analysis pipeline"""
        print("RUNNING CONGRESSIONAL POLARIZATION ANALYSIS PIPELINE")
        print("="*70)
        
        # Load and aggregate data
        self.load_pickle()
        self.aggregate_all_terms()
        
        # Analyze partisan distinctions
        self.analyze_partisan_distinctions(top_n)
        
        # Print detailed analysis
        self.print_partisan_comparison()
        
        # Get trend summary
        evolution_df = self.get_polarization_trend_summary()
        
        return self.polarization_analysis, evolution_df

# Usage example
def main():
    pipeline = PolarizationAnalysisPipeline("../feature_importance/congress_feature_importance_bigram_100_min_df_svm.pkl")
    
    # Run full analysis
    analysis, evolution_df = pipeline.run_polarization_pipeline(top_n=20)
    
    # Optional: Compare specific congresses
    if len(evolution_df) >= 2:
        congress_list = sorted(evolution_df['congress'].tolist())
        pipeline.compare_congress_polarization(congress_list[0], congress_list[-1])
    
    return pipeline, analysis, evolution_df

if __name__ == "__main__":
    pipeline, analysis, evolution_df = main()
# Out:
# RUNNING CONGRESSIONAL POLARIZATION ANALYSIS PIPELINE
# ======================================================================
# Loading pickle file...
# Loaded data for 36 congress sessions: [76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111]
# Using 3 seeds: [42, 123, 789]
# Aggregating coefficients across seeds...
#
# Analyzing top 20 partisan distinguishing terms per congress...
#
# ================================================================================
# PARTISAN LANGUAGE DISTINCTION ANALYSIS
# ================================================================================
#
# CONGRESS 76
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. new deal        (coeff: +9.745)
#    2. taxpayer        (coeff: +5.493)
#    3. new             (coeff: +4.489)
#    4. spend           (coeff: +3.894)
#    5. spending        (coeff: +3.730)
#    6. share           (coeff: +3.712)
#    7. codification    (coeff: +3.622)
#    8. power president (coeff: +3.548)
#    9. canadian        (coeff: +3.523)
#   10. reserve right   (coeff: +3.523)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. friend          (coeff: -5.544)
#    2. undertake       (coeff: -5.445)
#    3. senator         (coeff: -4.881)
#    4. section country (coeff: -3.809)
#    5. necessary       (coeff: -3.447)
#    6. pest            (coeff: -3.251)
#    7. provision       (coeff: -3.209)
#    8. enable          (coeff: -3.123)
#    9. certify         (coeff: -3.098)
#   10. committee       (coeff: -3.042)
#
# CONGRESS 77
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. foreign nation  (coeff: +2.208)
#    2. new deal        (coeff: +2.129)
#    3. identify        (coeff: +1.820)
#    4. confes          (coeff: +1.750)
#    5. presently       (coeff: +1.736)
#    6. administration  (coeff: +1.718)
#    7. spending        (coeff: +1.715)
#    8. apparent        (coeff: +1.667)
#    9. amortization    (coeff: +1.664)
#   10. belligerent     (coeff: +1.662)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. invite attention (coeff: -1.947)
#    2. magnesium       (coeff: -1.861)
#    3. ask unanimous   (coeff: -1.786)
#    4. gentleman object (coeff: -1.718)
#    5. pacific northwest (coeff: -1.713)
#    6. recommendation president (coeff: -1.708)
#    7. state union     (coeff: -1.696)
#    8. tobacco         (coeff: -1.684)
#    9. travel expense  (coeff: -1.625)
#   10. unquestionably  (coeff: -1.616)
#
# CONGRESS 78
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. distinguished chairman (coeff: +2.509)
#    2. new deal        (coeff: +2.244)
#    3. consumer subsidy (coeff: +2.179)
#    4. manpower        (coeff: +2.102)
#    5. fourth          (coeff: +1.906)
#    6. inquire         (coeff: +1.809)
#    7. introduce resolution (coeff: +1.754)
#    8. corn            (coeff: +1.733)
#    9. administration  (coeff: +1.722)
#   10. ask chairman    (coeff: +1.695)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. enable          (coeff: -2.165)
#    2. margarine       (coeff: -1.837)
#    3. foreign service (coeff: -1.815)
#    4. calculate       (coeff: -1.814)
#    5. reference       (coeff: -1.771)
#    6. natural rubber  (coeff: -1.758)
#    7. utilize         (coeff: -1.723)
#    8. connect         (coeff: -1.713)
#    9. use subsidy     (coeff: -1.680)
#   10. patent          (coeff: -1.678)
#
# CONGRESS 79
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. spending        (coeff: +2.201)
#    2. amputee         (coeff: +2.124)
#    3. folk            (coeff: +2.096)
#    4. administration  (coeff: +1.966)
#    5. labor leader    (coeff: +1.882)
#    6. story           (coeff: +1.823)
#    7. new deal        (coeff: +1.735)
#    8. respect         (coeff: +1.733)
#    9. bankrupt        (coeff: +1.727)
#   10. objector        (coeff: +1.616)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. democracy       (coeff: -1.964)
#    2. point order     (coeff: -1.858)
#    3. unfortunately   (coeff: -1.679)
#    4. aim             (coeff: -1.633)
#    5. executive agreement (coeff: -1.612)
#    6. yield question  (coeff: -1.584)
#    7. desire          (coeff: -1.580)
#    8. strip           (coeff: -1.574)
#    9. gain            (coeff: -1.563)
#   10. deal law        (coeff: -1.549)
#
# CONGRESS 80
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. administration  (coeff: +2.516)
#    2. obviously       (coeff: +1.940)
#    3. republic        (coeff: +1.935)
#    4. good friend     (coeff: +1.899)
#    5. suggest         (coeff: +1.863)
#    6. small business  (coeff: +1.767)
#    7. idea            (coeff: +1.746)
#    8. cigarette tax   (coeff: +1.523)
#    9. spending        (coeff: +1.512)
#   10. stop communism  (coeff: +1.510)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. democracy       (coeff: -2.213)
#    2. bondholder      (coeff: -1.689)
#    3. majority        (coeff: -1.678)
#    4. advertising     (coeff: -1.673)
#    5. steel plant     (coeff: -1.665)
#    6. south           (coeff: -1.601)
#    7. unwarranted     (coeff: -1.559)
#    8. faithful        (coeff: -1.535)
#    9. heretofore      (coeff: -1.529)
#   10. religious       (coeff: -1.510)
#
# CONGRESS 81
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. subparagraph    (coeff: +1.800)
#    2. presently       (coeff: +1.775)
#    3. apparently      (coeff: +1.774)
#    4. undoubtedly     (coeff: +1.761)
#    5. township        (coeff: +1.703)
#    6. taxpayer        (coeff: +1.685)
#    7. respect         (coeff: +1.634)
#    8. pacific         (coeff: +1.618)
#    9. chairman yield  (coeff: +1.609)
#   10. inquire         (coeff: +1.604)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. relation        (coeff: -2.091)
#    2. opposition amendment (coeff: -2.013)
#    3. democracy       (coeff: -1.829)
#    4. negro           (coeff: -1.757)
#    5. yield minute    (coeff: -1.746)
#    6. income tax      (coeff: -1.732)
#    7. margarine       (coeff: -1.729)
#    8. big business    (coeff: -1.685)
#    9. plain           (coeff: -1.674)
#   10. speaker purpose (coeff: -1.670)
#
# CONGRESS 82
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. administration  (coeff: +2.964)
#    2. review          (coeff: +2.099)
#    3. medicine        (coeff: +1.784)
#    4. secondly        (coeff: +1.768)
#    5. wonder          (coeff: +1.764)
#    6. respect         (coeff: +1.741)
#    7. abroad          (coeff: +1.689)
#    8. presently       (coeff: +1.619)
#    9. spending        (coeff: +1.607)
#   10. rise support    (coeff: +1.591)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. democracy       (coeff: -2.322)
#    2. cotton          (coeff: -1.859)
#    3. inland          (coeff: -1.781)
#    4. opposition      (coeff: -1.746)
#    5. order business  (coeff: -1.696)
#    6. dime            (coeff: -1.630)
#    7. electricity     (coeff: -1.628)
#    8. support measure (coeff: -1.593)
#    9. democratic      (coeff: -1.588)
#   10. speaker ask     (coeff: -1.569)
#
# CONGRESS 83
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. good friend     (coeff: +2.130)
#    2. foreigner       (coeff: +1.865)
#    3. ask unanimous   (coeff: +1.736)
#    4. impossible      (coeff: +1.710)
#    5. spending        (coeff: +1.673)
#    6. respect         (coeff: +1.656)
#    7. gi              (coeff: +1.639)
#    8. rise opposition (coeff: +1.629)
#    9. sort            (coeff: +1.582)
#   10. conviction      (coeff: +1.576)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. democratic      (coeff: -2.065)
#    2. present administration (coeff: -1.721)
#    3. distinguished   (coeff: -1.689)
#    4. angle           (coeff: -1.679)
#    5. charity         (coeff: -1.637)
#    6. observation     (coeff: -1.611)
#    7. reach           (coeff: -1.605)
#    8. extra           (coeff: -1.597)
#    9. quota           (coeff: -1.594)
#   10. repeal          (coeff: -1.557)
#
# CONGRESS 84
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. pass prejudice  (coeff: +2.659)
#    2. introduce distinguished (coeff: +2.123)
#    3. chairman time   (coeff: +1.937)
#    4. request time    (coeff: +1.805)
#    5. taxpayer country (coeff: +1.801)
#    6. encourage       (coeff: +1.728)
#    7. respect         (coeff: +1.692)
#    8. junket          (coeff: +1.605)
#    9. want associate  (coeff: +1.396)
#   10. message announce (coeff: +1.395)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. democracy       (coeff: -2.197)
#    2. section country (coeff: -1.801)
#    3. occupy          (coeff: -1.718)
#    4. destroy         (coeff: -1.560)
#    5. primary         (coeff: -1.554)
#    6. democratic      (coeff: -1.516)
#    7. response question (coeff: -1.482)
#    8. observation     (coeff: -1.473)
#    9. contractor      (coeff: -1.449)
#   10. prohibit        (coeff: -1.448)
#
# CONGRESS 85
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. spending        (coeff: +2.045)
#    2. likewise        (coeff: +1.953)
#    3. speaker rise    (coeff: +1.846)
#    4. greatly         (coeff: +1.696)
#    5. interference    (coeff: +1.611)
#    6. ahead           (coeff: +1.581)
#    7. pass prejudice  (coeff: +1.568)
#    8. favorable consideration (coeff: +1.558)
#    9. western states  (coeff: +1.558)
#   10. question amendment (coeff: +1.550)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. friend          (coeff: -2.602)
#    2. democracy       (coeff: -2.550)
#    3. frank           (coeff: -2.114)
#    4. speaker purpose (coeff: -1.826)
#    5. announcement    (coeff: -1.815)
#    6. margarine       (coeff: -1.613)
#    7. great body      (coeff: -1.586)
#    8. race            (coeff: -1.551)
#    9. decent          (coeff: -1.549)
#   10. able chairman   (coeff: -1.548)
#
# CONGRESS 86
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. spending        (coeff: +2.305)
#    2. speaker legislation (coeff: +2.299)
#    3. furthermore     (coeff: +2.128)
#    4. request time    (coeff: +1.757)
#    5. gentleman explain (coeff: +1.752)
#    6. previous        (coeff: +1.702)
#    7. costly          (coeff: +1.690)
#    8. seneca          (coeff: +1.650)
#    9. raise wheat     (coeff: +1.640)
#   10. essentially     (coeff: +1.630)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. friend          (coeff: -2.001)
#    2. introduce colleague (coeff: -1.849)
#    3. distinguished   (coeff: -1.812)
#    4. page line       (coeff: -1.605)
#    5. previous question (coeff: -1.598)
#    6. country think   (coeff: -1.562)
#    7. unanimous consent (coeff: -1.553)
#    8. location        (coeff: -1.540)
#    9. speaker purpose (coeff: -1.528)
#   10. architect       (coeff: -1.513)
#
# CONGRESS 87
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. wonder          (coeff: +2.175)
#    2. likewise        (coeff: +1.948)
#    3. administration  (coeff: +1.922)
#    4. spending        (coeff: +1.828)
#    5. ask gentleman   (coeff: +1.763)
#    6. prejudice       (coeff: +1.752)
#    7. foreign giveaway (coeff: +1.740)
#    8. cancer research (coeff: +1.717)
#    9. handout         (coeff: +1.709)
#   10. taxpayer        (coeff: +1.674)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. distinguished   (coeff: -2.442)
#    2. friend          (coeff: -2.292)
#    3. democracy       (coeff: -2.135)
#    4. opponent        (coeff: -2.120)
#    5. unemployment area (coeff: -2.018)
#    6. fact matter     (coeff: -1.921)
#    7. previous administration (coeff: -1.830)
#    8. speaker purpose (coeff: -1.724)
#    9. splendid        (coeff: -1.723)
#   10. past administration (coeff: -1.632)
#
# CONGRESS 88
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. taxpayer        (coeff: +2.684)
#    2. apparently      (coeff: +2.579)
#    3. outstanding young (coeff: +2.158)
#    4. clarify         (coeff: +2.031)
#    5. wonder          (coeff: +1.983)
#    6. administration  (coeff: +1.976)
#    7. pass prejudice  (coeff: +1.905)
#    8. reason race     (coeff: +1.897)
#    9. let ask         (coeff: +1.821)
#   10. pacific northwest (coeff: +1.810)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. democratic      (coeff: -2.297)
#    2. distinguished   (coeff: -2.118)
#    3. honorable       (coeff: -1.980)
#    4. speaker purpose (coeff: -1.782)
#    5. choice          (coeff: -1.768)
#    6. friend          (coeff: -1.756)
#    7. pende           (coeff: -1.749)
#    8. pende yield     (coeff: -1.722)
#    9. speaker direction (coeff: -1.693)
#   10. impressive      (coeff: -1.669)
#
# CONGRESS 89
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. administration  (coeff: +2.911)
#    2. taxpayer        (coeff: +2.831)
#    3. spending        (coeff: +2.505)
#    4. apparently      (coeff: +2.322)
#    5. republican      (coeff: +2.115)
#    6. rise support    (coeff: +2.040)
#    7. reserve right   (coeff: +2.000)
#    8. aisle           (coeff: +1.972)
#    9. point remark    (coeff: +1.931)
#   10. presently       (coeff: +1.921)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. gentleman pende (coeff: -2.222)
#    2. pende yield     (coeff: -2.180)
#    3. republican friend (coeff: -2.123)
#    4. republican administration (coeff: -1.895)
#    5. democracy       (coeff: -1.741)
#    6. foster          (coeff: -1.722)
#    7. read gentleman  (coeff: -1.713)
#    8. rise opposition (coeff: -1.701)
#    9. previous question (coeff: -1.688)
#   10. jet noise       (coeff: -1.658)
#
# CONGRESS 90
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. administration  (coeff: +3.209)
#    2. rise support    (coeff: +2.596)
#    3. minority view   (coeff: +2.444)
#    4. taxpayer        (coeff: +2.198)
#    5. demonstration city (coeff: +2.085)
#    6. human investment (coeff: +2.055)
#    7. spending limitation (coeff: +2.038)
#    8. wonder          (coeff: +2.007)
#    9. manipulation    (coeff: +1.938)
#   10. tax credit      (coeff: +1.913)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. pende yield     (coeff: -2.575)
#    2. surcharge       (coeff: -2.290)
#    3. gentleman pende (coeff: -2.123)
#    4. republican friend (coeff: -2.112)
#    5. remark include  (coeff: -1.953)
#    6. follow remark   (coeff: -1.923)
#    7. democratic      (coeff: -1.920)
#    8. present committee (coeff: -1.867)
#    9. enactment       (coeff: -1.849)
#   10. speaker purpose (coeff: -1.822)
#
# CONGRESS 91
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. speaker president (coeff: +2.510)
#    2. democratic administration (coeff: +2.494)
#    3. republican      (coeff: +2.328)
#    4. congressional reform (coeff: +2.098)
#    5. taxpayer country (coeff: +2.074)
#    6. pretrial        (coeff: +2.044)
#    7. allvolunteer    (coeff: +1.939)
#    8. pretrial detention (coeff: +1.899)
#    9. pass judgment   (coeff: +1.883)
#   10. forward funding (coeff: +1.880)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. pende yield     (coeff: -2.468)
#    2. minority leader (coeff: -2.014)
#    3. gentleman pende (coeff: -1.975)
#    4. pende           (coeff: -1.939)
#    5. saving loan     (coeff: -1.901)
#    6. splendid        (coeff: -1.897)
#    7. democratic      (coeff: -1.816)
#    8. matter great    (coeff: -1.738)
#    9. decent          (coeff: -1.722)
#   10. brilliant       (coeff: -1.707)
#
# CONGRESS 92
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. honesty         (coeff: +2.163)
#    2. support passage (coeff: +2.083)
#    3. distinguished majority (coeff: +1.948)
#    4. critic          (coeff: +1.889)
#    5. republican      (coeff: +1.884)
#    6. rise time       (coeff: +1.825)
#    7. flexible        (coeff: +1.779)
#    8. invader         (coeff: +1.761)
#    9. think important (coeff: +1.727)
#   10. village         (coeff: +1.699)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. pende yield     (coeff: -2.292)
#    2. gentleman pende (coeff: -2.085)
#    3. ask unanimous   (coeff: -1.709)
#    4. cruise          (coeff: -1.650)
#    5. absent          (coeff: -1.616)
#    6. democracy       (coeff: -1.602)
#    7. assure gentleman (coeff: -1.546)
#    8. miss rollcall   (coeff: -1.534)
#    9. education act   (coeff: -1.521)
#   10. space shuttle   (coeff: -1.516)
#
# CONGRESS 93
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. provide consideration (coeff: +1.964)
#    2. speaker support (coeff: +1.823)
#    3. bureaucracy     (coeff: +1.790)
#    4. appreciate gentleman (coeff: +1.745)
#    5. speaker request (coeff: +1.669)
#    6. confrontation   (coeff: +1.666)
#    7. republican      (coeff: +1.662)
#    8. inaction        (coeff: +1.624)
#    9. thank gentleman (coeff: +1.623)
#   10. taxpayer        (coeff: +1.596)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. pende yield     (coeff: -2.309)
#    2. gentleman pende (coeff: -1.747)
#    3. state union     (coeff: -1.611)
#    4. matter          (coeff: -1.592)
#    5. democratic      (coeff: -1.550)
#    6. resolution order (coeff: -1.503)
#    7. seek            (coeff: -1.407)
#    8. progressive     (coeff: -1.391)
#    9. precisely       (coeff: -1.359)
#   10. ask amendment   (coeff: -1.358)
#
# CONGRESS 94
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. speaker support (coeff: +2.530)
#    2. minority view   (coeff: +2.321)
#    3. shall vote      (coeff: +2.267)
#    4. ceiling price   (coeff: +2.179)
#    5. appreciate colleague (coeff: +2.174)
#    6. majority party  (coeff: +2.167)
#    7. tell friend     (coeff: +2.113)
#    8. speaker reserve (coeff: +2.050)
#    9. taxpayer        (coeff: +1.938)
#   10. extra           (coeff: +1.927)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. pende yield     (coeff: -3.867)
#    2. gentleman pende (coeff: -2.746)
#    3. speaker suspend (coeff: -1.796)
#    4. new member      (coeff: -1.795)
#    5. object like     (coeff: -1.776)
#    6. rule hour       (coeff: -1.715)
#    7. state gentleman (coeff: -1.699)
#    8. democracy       (coeff: -1.691)
#    9. arrive          (coeff: -1.547)
#   10. append          (coeff: -1.545)
#
# CONGRESS 95
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. republican      (coeff: +2.460)
#    2. rise support    (coeff: +2.421)
#    3. accordingly urge (coeff: +2.395)
#    4. vote following  (coeff: +2.257)
#    5. communist       (coeff: +2.138)
#    6. speaker support (coeff: +2.109)
#    7. colleague yield (coeff: +2.090)
#    8. request time    (coeff: +2.045)
#    9. majority        (coeff: +1.968)
#   10. acknowledge     (coeff: +1.888)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. gentleman pende (coeff: -3.312)
#    2. pende yield     (coeff: -3.194)
#    3. speaker suspend (coeff: -2.049)
#    4. bitter          (coeff: -1.854)
#    5. ask unanimous   (coeff: -1.799)
#    6. unelected       (coeff: -1.791)
#    7. german          (coeff: -1.742)
#    8. matter          (coeff: -1.738)
#    9. democratic      (coeff: -1.733)
#   10. needy           (coeff: -1.720)
#
# CONGRESS 96
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. colleague yield (coeff: +2.485)
#    2. communist       (coeff: +2.235)
#    3. taxpayer        (coeff: +2.153)
#    4. ranking member  (coeff: +1.843)
#    5. speaker yield   (coeff: +1.718)
#    6. majority        (coeff: +1.703)
#    7. evidently       (coeff: +1.698)
#    8. republican      (coeff: +1.634)
#    9. sandinista      (coeff: +1.578)
#   10. lameduck        (coeff: +1.539)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. pende yield     (coeff: -2.414)
#    2. gentleman pende (coeff: -1.771)
#    3. northwest       (coeff: -1.756)
#    4. question order  (coeff: -1.648)
#    5. tape            (coeff: -1.523)
#    6. ask unanimous   (coeff: -1.520)
#    7. foreign tax     (coeff: -1.492)
#    8. distinguished friend (coeff: -1.469)
#    9. systematic      (coeff: -1.461)
#   10. speaker suspend (coeff: -1.396)
#
# CONGRESS 97
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. rise support    (coeff: +2.582)
#    2. democratic leadership (coeff: +2.343)
#    3. tax rate        (coeff: +2.336)
#    4. communist       (coeff: +2.273)
#    5. accordingly urge (coeff: +2.086)
#    6. message announce (coeff: +1.992)
#    7. arm reduction   (coeff: +1.984)
#    8. ida             (coeff: +1.982)
#    9. biological      (coeff: +1.968)
#   10. freshman        (coeff: +1.947)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. depression      (coeff: -2.434)
#    2. decent          (coeff: -2.014)
#    3. pende yield     (coeff: -1.901)
#    4. gentleman pende (coeff: -1.801)
#    5. incredible      (coeff: -1.723)
#    6. military spending (coeff: -1.688)
#    7. middleincome    (coeff: -1.685)
#    8. waterway        (coeff: -1.682)
#    9. arm race        (coeff: -1.676)
#   10. defense spending (coeff: -1.653)
#
# CONGRESS 98
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. accordingly urge (coeff: +2.329)
#    2. rise support    (coeff: +2.152)
#    3. revolution      (coeff: +2.091)
#    4. free world      (coeff: +2.065)
#    5. spending        (coeff: +2.063)
#    6. object speaker  (coeff: +2.027)
#    7. budget amendment (coeff: +1.980)
#    8. liberal         (coeff: +1.972)
#    9. rank member     (coeff: +1.927)
#   10. chemical weapon (coeff: +1.895)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. opposition amendment (coeff: -2.390)
#    2. distinguished colleague (coeff: -2.134)
#    3. military        (coeff: -2.008)
#    4. reasonable period (coeff: -1.976)
#    5. purpose debate  (coeff: -1.909)
#    6. pende yield     (coeff: -1.886)
#    7. gentleman correct (coeff: -1.750)
#    8. formal          (coeff: -1.713)
#    9. problem amendment (coeff: -1.674)
#   10. bipartisan support (coeff: -1.672)
#
# CONGRESS 99
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. accordingly urge (coeff: +2.514)
#    2. ranking republican (coeff: +2.254)
#    3. communist       (coeff: +2.167)
#    4. price cut       (coeff: +2.145)
#    5. right object    (coeff: +1.979)
#    6. accordingly     (coeff: +1.937)
#    7. majority party  (coeff: +1.842)
#    8. matter fact     (coeff: +1.814)
#    9. peacekeeper     (coeff: +1.775)
#   10. inquire         (coeff: +1.768)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. speaker suspend (coeff: -2.414)
#    2. sensible        (coeff: -1.969)
#    3. star war        (coeff: -1.961)
#    4. administrations (coeff: -1.941)
#    5. contra          (coeff: -1.917)
#    6. overthrow       (coeff: -1.781)
#    7. chairman rise   (coeff: -1.765)
#    8. administration  (coeff: -1.718)
#    9. purpose debate  (coeff: -1.702)
#   10. gentleman suggest (coeff: -1.663)
#
# CONGRESS 100
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. accordingly urge (coeff: +3.525)
#    2. vice chairman   (coeff: +3.048)
#    3. accordingly     (coeff: +3.014)
#    4. communist       (coeff: +2.615)
#    5. democratic leadership (coeff: +2.231)
#    6. right object    (coeff: +2.128)
#    7. free world      (coeff: +1.968)
#    8. democrat        (coeff: +1.958)
#    9. present form    (coeff: +1.882)
#   10. soviets         (coeff: +1.845)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. contra          (coeff: -2.135)
#    2. administrations (coeff: -1.968)
#    3. administration  (coeff: -1.956)
#    4. question resolution (coeff: -1.888)
#    5. generic         (coeff: -1.806)
#    6. speaker suspend (coeff: -1.792)
#    7. extent          (coeff: -1.786)
#    8. disabled        (coeff: -1.785)
#    9. arm race        (coeff: -1.779)
#   10. opposition amendment (coeff: -1.744)
#
# CONGRESS 101
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. accordingly     (coeff: +3.285)
#    2. vice chairman   (coeff: +2.978)
#    3. communist       (coeff: +2.579)
#    4. liberal         (coeff: +2.318)
#    5. accordingly urge (coeff: +2.196)
#    6. spending        (coeff: +2.159)
#    7. administration support (coeff: +2.103)
#    8. right object    (coeff: +2.103)
#    9. rise support    (coeff: +1.946)
#   10. democratic leadership (coeff: +1.936)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. wealthy         (coeff: -3.075)
#    2. tax cut         (coeff: -1.888)
#    3. administration  (coeff: -1.852)
#    4. rights          (coeff: -1.735)
#    5. speaker purpose (coeff: -1.726)
#    6. pursuant        (coeff: -1.719)
#    7. star war        (coeff: -1.663)
#    8. time previous   (coeff: -1.634)
#    9. democrats republicans (coeff: -1.633)
#   10. country world   (coeff: -1.617)
#
# CONGRESS 102
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. democrats       (coeff: +2.631)
#    2. liberal         (coeff: +2.623)
#    3. communist       (coeff: +2.476)
#    4. democratic leadership (coeff: +2.396)
#    5. democrat        (coeff: +2.252)
#    6. spending        (coeff: +2.075)
#    7. little early    (coeff: +2.064)
#    8. ranking republican (coeff: +2.040)
#    9. guy             (coeff: +1.987)
#   10. rank member     (coeff: +1.953)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. confront        (coeff: -2.344)
#    2. administration  (coeff: -2.274)
#    3. democrats republicans (coeff: -1.911)
#    4. exhaust         (coeff: -1.765)
#    5. chairman rise   (coeff: -1.748)
#    6. opposition motion (coeff: -1.744)
#    7. time previous   (coeff: -1.730)
#    8. affection       (coeff: -1.665)
#    9. introduce colleague (coeff: -1.662)
#   10. committee yield (coeff: -1.649)
#
# CONGRESS 103
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. democrat        (coeff: +2.658)
#    2. accordingly     (coeff: +2.622)
#    3. bureaucrat      (coeff: +2.407)
#    4. accordingly urge (coeff: +2.373)
#    5. democratic leadership (coeff: +2.194)
#    6. rise support    (coeff: +2.159)
#    7. opposition rule (coeff: +2.072)
#    8. cosponsor       (coeff: +2.064)
#    9. sovereignty     (coeff: +1.983)
#   10. term limit      (coeff: +1.938)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. opposition amendment (coeff: -2.827)
#    2. speaker suspend (coeff: -2.194)
#    3. tax break       (coeff: -2.162)
#    4. chairman rise   (coeff: -2.027)
#    5. wealthy         (coeff: -1.922)
#    6. criminal investigation (coeff: -1.895)
#    7. urge member     (coeff: -1.852)
#    8. worker          (coeff: -1.824)
#    9. proponent amendment (coeff: -1.725)
#   10. serbs           (coeff: -1.718)
#
# CONGRESS 104
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. opposition amendment (coeff: +3.093)
#    2. liberal         (coeff: +2.907)
#    3. bureaucrat      (coeff: +2.790)
#    4. democrat        (coeff: +2.500)
#    5. bureaucracy     (coeff: +2.225)
#    6. administration  (coeff: +2.125)
#    7. communist       (coeff: +2.125)
#    8. accordingly     (coeff: +2.106)
#    9. frankly         (coeff: +2.103)
#   10. businessman     (coeff: +2.038)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. republican colleague (coeff: -3.421)
#    2. republican      (coeff: -3.180)
#    3. republicans     (coeff: -3.076)
#    4. speaker support (coeff: -2.777)
#    5. republican leadership (coeff: -2.501)
#    6. majority        (coeff: -2.444)
#    7. support substitute (coeff: -2.383)
#    8. let simply      (coeff: -2.334)
#    9. beam            (coeff: -2.224)
#   10. wealthy         (coeff: -2.190)
#
# CONGRESS 105
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. bureaucracy     (coeff: +2.835)
#    2. bureaucrat      (coeff: +2.818)
#    3. liberal         (coeff: +2.646)
#    4. democrat        (coeff: +2.439)
#    5. accordingly     (coeff: +1.885)
#    6. actually        (coeff: +1.875)
#    7. opposition amendment (coeff: +1.865)
#    8. spending        (coeff: +1.829)
#    9. protection act  (coeff: +1.828)
#   10. speaker suspend (coeff: +1.815)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. democratic      (coeff: -2.805)
#    2. beam            (coeff: -2.775)
#    3. republican      (coeff: -2.768)
#    4. tax break       (coeff: -2.652)
#    5. let simply      (coeff: -2.381)
#    6. ought           (coeff: -2.199)
#    7. finance reform  (coeff: -2.069)
#    8. rights          (coeff: -2.015)
#    9. majority        (coeff: -2.004)
#   10. republican colleague (coeff: -1.976)
#
# CONGRESS 106
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. death tax       (coeff: +2.552)
#    2. bureaucracy     (coeff: +2.449)
#    3. support rule    (coeff: +2.431)
#    4. speaker suspend (coeff: +2.396)
#    5. administration  (coeff: +2.097)
#    6. liberal         (coeff: +2.091)
#    7. exactly         (coeff: +2.090)
#    8. oppose amendment (coeff: +2.032)
#    9. democrat        (coeff: +2.013)
#   10. republicans democrats (coeff: +1.947)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. beam            (coeff: -5.016)
#    2. majority        (coeff: -3.431)
#    3. republican leadership (coeff: -2.902)
#    4. member yield    (coeff: -2.862)
#    5. tax break       (coeff: -2.585)
#    6. support motion  (coeff: -2.490)
#    7. republican colleague (coeff: -2.336)
#    8. rights          (coeff: -2.248)
#    9. abolish         (coeff: -2.228)
#   10. republican      (coeff: -2.140)
#
# CONGRESS 107
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. accordingly     (coeff: +3.144)
#    2. opposition amendment (coeff: +2.218)
#    3. accordingly urge (coeff: +2.072)
#    4. death tax       (coeff: +1.995)
#    5. member support  (coeff: +1.976)
#    6. speaker suspend (coeff: +1.965)
#    7. underlie legislation (coeff: +1.931)
#    8. support rule    (coeff: +1.930)
#    9. liberal         (coeff: +1.915)
#   10. type            (coeff: +1.908)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. beam            (coeff: -3.067)
#    2. republican      (coeff: -2.972)
#    3. profit          (coeff: -2.358)
#    4. majority        (coeff: -2.148)
#    5. independent     (coeff: -2.132)
#    6. democratic      (coeff: -2.011)
#    7. indicate        (coeff: -1.922)
#    8. unilateral      (coeff: -1.914)
#    9. join colleague  (coeff: -1.901)
#   10. ranking democrat (coeff: -1.866)
#
# CONGRESS 108
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. support rule    (coeff: +2.692)
#    2. freedom         (coeff: +2.494)
#    3. regime          (coeff: +2.428)
#    4. speaker suspend (coeff: +2.365)
#    5. reserve balance (coeff: +2.282)
#    6. bless troop     (coeff: +2.071)
#    7. bless           (coeff: +2.027)
#    8. death tax       (coeff: +2.011)
#    9. speaker reserve (coeff: +2.007)
#   10. democrat        (coeff: +1.997)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. administration  (coeff: -3.533)
#    2. republican      (coeff: -2.982)
#    3. support motion  (coeff: -2.607)
#    4. republicans     (coeff: -2.481)
#    5. support substitute (coeff: -2.469)
#    6. majority        (coeff: -2.317)
#    7. join colleague  (coeff: -2.145)
#    8. democracy       (coeff: -1.978)
#    9. noncontroversial (coeff: -1.940)
#   10. undermine       (coeff: -1.878)
#
# CONGRESS 109
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. support rule    (coeff: +3.148)
#    2. speaker suspend (coeff: +3.053)
#    3. reserve balance (coeff: +2.609)
#    4. democrat        (coeff: +2.299)
#    5. speaker reserve (coeff: +2.253)
#    6. dictator        (coeff: +2.190)
#    7. reform          (coeff: +2.158)
#    8. freedom         (coeff: +2.121)
#    9. spending        (coeff: +2.119)
#   10. private property (coeff: +2.054)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. administration  (coeff: -3.313)
#    2. republican      (coeff: -2.727)
#    3. majority        (coeff: -2.464)
#    4. yield friend    (coeff: -2.366)
#    5. borrow          (coeff: -2.327)
#    6. gentleman information (coeff: -2.092)
#    7. democratic      (coeff: -2.066)
#    8. chairman ranking (coeff: -2.065)
#    9. privatization   (coeff: -2.002)
#   10. debt            (coeff: -1.979)
#
# CONGRESS 110
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. democrat        (coeff: +3.570)
#    2. majority        (coeff: +2.970)
#    3. spending        (coeff: +2.461)
#    4. freedom         (coeff: +2.460)
#    5. consume rise    (coeff: +2.429)
#    6. american energy (coeff: +2.259)
#    7. appreciate chairman (coeff: +2.248)
#    8. radical         (coeff: +2.227)
#    9. rise opposition (coeff: +2.204)
#   10. yield balance   (coeff: +2.188)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. speaker suspend (coeff: -3.248)
#    2. administration  (coeff: -2.909)
#    3. opposition amendment (coeff: -2.559)
#    4. support rule    (coeff: -2.308)
#    5. escalation      (coeff: -2.195)
#    6. resolution yield (coeff: -2.190)
#    7. let thank       (coeff: -2.016)
#    8. clean energy    (coeff: -1.978)
#    9. republican colleague (coeff: -1.933)
#   10. administrations (coeff: -1.882)
#
# CONGRESS 111
# --------------------------------------------------
#
# TOP REPUBLICAN-DISTINGUISHING TERMS:
#   (Positive coefficients - algorithm associates these with Republicans)
#    1. democrat        (coeff: +3.132)
#    2. majority        (coeff: +2.964)
#    3. consume rise    (coeff: +2.943)
#    4. taxis           (coeff: +2.688)
#    5. unfortunately   (coeff: +2.681)
#    6. bureaucracy     (coeff: +2.308)
#    7. spending        (coeff: +2.269)
#    8. bureaucrat      (coeff: +2.269)
#    9. speaker rollcall (coeff: +2.148)
#   10. capandtax       (coeff: +2.126)
#
# TOP DEMOCRAT-DISTINGUISHING TERMS:
#   (Negative coefficients - algorithm associates these with Democrats)
#    1. speaker suspend (coeff: -3.236)
#    2. tax cut         (coeff: -3.233)
#    3. support rule    (coeff: -2.323)
#    4. progressive     (coeff: -2.311)
#    5. acknowledge     (coeff: -2.000)
#    6. recovery        (coeff: -1.989)
#    7. invest          (coeff: -1.982)
#    8. surplus         (coeff: -1.911)
#    9. speaker want    (coeff: -1.902)
#   10. diplomatic      (coeff: -1.826)
#
# POLARIZATION TREND SUMMARY
# ==================================================
# Period: Congress 76 → Congress 111
# Analysis shows evolution in partisan language patterns over time
#
# COMPARING CONGRESS 76 vs CONGRESS 111
# ============================================================
#
# Top Republican Terms Comparison:
#   Congress 76: new deal, taxpayer, new, spend, spending
#   Congress 111: democrat, majority, consume rise, taxis, unfortunately
#
# Top Democrat Terms Comparison:
#   Congress 76: friend, undertake, senator, section country, necessary
#   Congress 111: speaker suspend, tax cut, support rule, progressive, acknowledge
